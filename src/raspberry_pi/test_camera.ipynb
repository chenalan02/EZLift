# %%
import cv2
# from picamera2 import Picamera2
from ultralytics import YOLO
import os
os.environ["DISPLAY"] = ":0"

# %%
model_path = r"C:\Users\chena\Desktop\EZLift\model_training\runs\detect\pallets\weights\best.pt"
# model_path = '/home/pi/EZLift/model_training/runs/detect/pallets/weights/best_ncnn_model'
model = YOLO(model_path)

# %%
# model.export(format="ncnn")
model.export(format="tflite")
# Out:
# Ultralytics 8.3.81  Python-3.9.21 torch-2.6.0 CPU (11th Gen Intel Core(TM) i7-11700 2.50GHz)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients
#
# PyTorch: starting from 'C:\Users\chena\Desktop\EZLift\model_training\runs\detect\pallets\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (5.2 MB)
# requirements: Ultralytics requirement ['tensorflow-cpu>=2.0.0'] not found, attempting AutoUpdate...
# Collecting tensorflow-cpu>=2.0.0
#   Downloading tensorflow_cpu-2.18.0-cp39-cp39-win_amd64.whl.metadata (3.3 kB)
# Collecting tensorflow-intel==2.18.0 (from tensorflow-cpu>=2.0.0)
#   Downloading tensorflow_intel-2.18.0-cp39-cp39-win_amd64.whl.metadata (4.9 kB)
# Collecting absl-py>=1.0.0 (from tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0)
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0) (24.2)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0)
#   Downloading protobuf-5.29.3-cp39-cp39-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0) (75.8.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0)
#   Downloading termcolor-2.5.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0) (4.12.2)
# Collecting wrapt>=1.11.0 (from tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0)
#   Downloading wrapt-1.17.2-cp39-cp39-win_amd64.whl.metadata (6.5 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0)
#   Downloading grpcio-1.70.0-cp39-cp39-win_amd64.whl.metadata (4.0 kB)
# Collecting tensorboard<2.19,>=2.18 (from tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0)
#   Downloading tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.5.0 (from tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0)
#   Downloading keras-3.8.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0) (1.26.4)
# Collecting h5py>=3.11.0 (from tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0)
#   Downloading h5py-3.13.0-cp39-cp39-win_amd64.whl.metadata (2.5 kB)
# Collecting ml-dtypes<0.5.0,>=0.4.0 (from tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0)
#   Downloading ml_dtypes-0.4.1-cp39-cp39-win_amd64.whl.metadata (20 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0)
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp39-cp39-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0) (0.45.1)
# Collecting rich (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0)
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Requirement already satisfied: optree in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0) (0.14.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0) (2025.1.31)
# Collecting markdown>=2.6.8 (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0)
#   Downloading Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from markdown>=2.6.8->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0) (8.6.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0) (3.0.2)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0) (2.19.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0) (3.21.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow-cpu>=2.0.0)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow_cpu-2.18.0-cp39-cp39-win_amd64.whl (7.6 kB)
# Downloading tensorflow_intel-2.18.0-cp39-cp39-win_amd64.whl (390.0 MB)
#    --------------------------------------- 390.0/390.0 MB 10.4 MB/s eta 0:00:00
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.70.0-cp39-cp39-win_amd64.whl (4.3 MB)
#    ---------------------------------------- 4.3/4.3 MB 5.7 MB/s eta 0:00:00
# Downloading h5py-3.13.0-cp39-cp39-win_amd64.whl (3.0 MB)
#    ---------------------------------------- 3.0/3.0 MB 10.8 MB/s eta 0:00:00
# Downloading keras-3.8.0-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 1.3/1.3 MB 16.8 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
#    ---------------------------------------- 26.4/26.4 MB 10.6 MB/s eta 0:00:00
# Downloading ml_dtypes-0.4.1-cp39-cp39-win_amd64.whl (126 kB)
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading protobuf-5.29.3-cp39-cp39-win_amd64.whl (434 kB)
# Downloading tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 5.5/5.5 MB 10.8 MB/s eta 0:00:00
# Downloading tensorflow_io_gcs_filesystem-0.31.0-cp39-cp39-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 1.5/1.5 MB 13.0 MB/s eta 0:00:00
# Downloading termcolor-2.5.0-py3-none-any.whl (7.8 kB)
# Downloading wrapt-1.17.2-cp39-cp39-win_amd64.whl (38 kB)
# Downloading Markdown-3.7-py3-none-any.whl (106 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, werkzeug, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, protobuf, opt-einsum, ml-dtypes, mdurl, h5py, grpcio, google-pasta, gast, astunparse, absl-py, markdown-it-py, markdown, tensorboard, rich, keras, tensorflow-intel, tensorflow-cpu
# Successfully installed absl-py-2.1.0 astunparse-1.6.3 flatbuffers-25.2.10 gast-0.6.0 google-pasta-0.2.0 grpcio-1.70.0 h5py-3.13.0 keras-3.8.0 libclang-18.1.1 markdown-3.7 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.4.1 namex-0.0.8 opt-einsum-3.4.0 protobuf-5.29.3 rich-13.9.4 tensorboard-2.18.0 tensorboard-data-server-0.7.2 tensorflow-cpu-2.18.0 tensorflow-intel-2.18.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.5.0 werkzeug-3.1.3 wrapt-1.17.2
#
# requirements: AutoUpdate success  71.7s, installed 1 package: ['tensorflow-cpu>=2.0.0']
# requirements:  Restart runtime or rerun command for updates to take effect
#
# requirements: Ultralytics requirements ['tf_keras', 'sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'onnx>=1.12.0', 'onnx2tf>1.17.5,<=1.26.3', 'onnxslim>=0.1.31', 'tflite_support', 'onnxruntime'] not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting tf_keras
#   Downloading tf_keras-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting sng4onnx>=1.0.1
#   Downloading sng4onnx-1.0.4-py3-none-any.whl.metadata (4.6 kB)
# Collecting onnx_graphsurgeon>=0.3.26
#   Downloading onnx_graphsurgeon-0.5.5-py2.py3-none-any.whl.metadata (8.2 kB)
# Collecting onnx>=1.12.0
#   Downloading onnx-1.17.0-cp39-cp39-win_amd64.whl.metadata (16 kB)
# Collecting onnx2tf<=1.26.3,>1.17.5
#   Downloading onnx2tf-1.20.0-py3-none-any.whl.metadata (130 kB)
# Collecting onnxslim>=0.1.31
#   Downloading onnxslim-0.1.48-py3-none-any.whl.metadata (4.6 kB)
# Collecting tflite_support
#   Downloading tflite_support-0.4.3-cp39-cp39-win_amd64.whl.metadata (2.4 kB)
# Collecting onnxruntime
#   Downloading onnxruntime-1.19.2-cp39-cp39-win_amd64.whl.metadata (4.7 kB)
# Collecting tensorflow<2.19,>=2.18 (from tf_keras)
#   Downloading tensorflow-2.18.0-cp39-cp39-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: numpy in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from onnx_graphsurgeon>=0.3.26) (1.26.4)
# Requirement already satisfied: protobuf>=3.20.2 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from onnx>=1.12.0) (5.29.3)
# Requirement already satisfied: sympy in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from onnxslim>=0.1.31) (1.13.3)
# Requirement already satisfied: packaging in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from onnxslim>=0.1.31) (24.2)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tflite_support) (2.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tflite_support) (25.2.10)
# Collecting protobuf>=3.20.2 (from onnx>=1.12.0)
#   Downloading protobuf-3.20.3-cp39-cp39-win_amd64.whl.metadata (699 bytes)
# Collecting sounddevice>=0.4.4 (from tflite_support)
#   Downloading sounddevice-0.5.1-py3-none-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: pybind11>=2.6.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tflite_support) (2.13.6)
# Collecting coloredlogs (from onnxruntime)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: CFFI>=1.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from sounddevice>=0.4.4->tflite_support) (1.17.1)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow<2.19,>=2.18->tf_keras) (2.18.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (1.6.3)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (3.4.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (75.8.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (0.31.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from sympy->onnxslim>=0.1.31) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->tflite_support) (2.22)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime)
#   Downloading pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (0.45.1)
# Requirement already satisfied: rich in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (13.9.4)
# Requirement already satisfied: namex in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (0.0.8)
# Requirement already satisfied: optree in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (0.14.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (3.1.3)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from markdown>=2.6.8->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (8.6.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (2.19.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\chena\anaconda3\envs\tflite\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf_keras) (0.1.2)
# Downloading tf_keras-2.18.0-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 1.7/1.7 MB 31.1 MB/s eta 0:00:00
# Downloading sng4onnx-1.0.4-py3-none-any.whl (5.9 kB)
# Downloading onnx_graphsurgeon-0.5.5-py2.py3-none-any.whl (57 kB)
# Downloading onnx-1.17.0-cp39-cp39-win_amd64.whl (14.5 MB)
#    ---------------------------------------- 14.5/14.5 MB 11.6 MB/s eta 0:00:00
# Downloading onnx2tf-1.20.0-py3-none-any.whl (412 kB)
# Downloading onnxslim-0.1.48-py3-none-any.whl (142 kB)
# Downloading tflite_support-0.4.3-cp39-cp39-win_amd64.whl (469 kB)
# Downloading onnxruntime-1.19.2-cp39-cp39-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 11.1/11.1 MB 10.8 MB/s eta 0:00:00
# Downloading protobuf-3.20.3-cp39-cp39-win_amd64.whl (904 kB)
#    --------------------------------------- 904.2/904.2 kB 13.7 MB/s eta 0:00:00
# Downloading sounddevice-0.5.1-py3-none-win_amd64.whl (363 kB)
# Downloading tensorflow-2.18.0-cp39-cp39-win_amd64.whl (7.5 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Installing collected packages: sng4onnx, pyreadline3, protobuf, onnx2tf, sounddevice, onnx, humanfriendly, tflite_support, onnxslim, onnx_graphsurgeon, coloredlogs, onnxruntime, tensorflow, tf_keras
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.3
#     Uninstalling protobuf-5.29.3:
#       Successfully uninstalled protobuf-5.29.3
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnx-1.17.0 onnx2tf-1.20.0 onnx_graphsurgeon-0.5.5 onnxruntime-1.19.2 onnxslim-0.1.48 protobuf-3.20.3 pyreadline3-3.5.4 sng4onnx-1.0.4 sounddevice-0.5.1 tensorflow-2.18.0 tf_keras-2.18.0 tflite_support-0.4.3
#
# requirements: AutoUpdate success  28.8s, installed 8 packages: ['tf_keras', 'sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'onnx>=1.12.0', 'onnx2tf>1.17.5,<=1.26.3', 'onnxslim>=0.1.31', 'tflite_support', 'onnxruntime']
# requirements:  Restart runtime or rerun command for updates to take effect
#
#
# TensorFlow SavedModel: starting export with tensorflow 2.18.0...
# WARNING:tensorflow:From c:\Users\chena\anaconda3\envs\tflite\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/calibration_image_sample_data_20x128x128x3_float32.npy.zip to 'calibration_image_sample_data_20x128x128x3_float32.npy.zip'...
# 100%|██████████| 1.11M/1.11M [00:00<00:00, 55.3MB/s]
# Unzipping calibration_image_sample_data_20x128x128x3_float32.npy.zip to C:\Users\chena\Desktop\EZLift\src\raspberry_pi\calibration_image_sample_data_20x128x128x3_float32.npy...: 100%|██████████| 1/1 [00:00<00:00, 77.13file/s]
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.48...
# ONNX: export success  1.3s, saved as 'C:\Users\chena\Desktop\EZLift\model_training\runs\detect\pallets\weights\best.onnx' (10.2 MB)
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.20.0...
# TensorFlow SavedModel: export success  123.8s, saved as 'C:\Users\chena\Desktop\EZLift\model_training\runs\detect\pallets\weights\best_saved_model' (25.7 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.18.0...
# TensorFlow Lite: export success  0.0s, saved as 'C:\Users\chena\Desktop\EZLift\model_training\runs\detect\pallets\weights\best_saved_model\best_float32.tflite' (10.2 MB)
#
# Export complete (124.2s)
# Results saved to C:\Users\chena\Desktop\EZLift\model_training\runs\detect\pallets\weights
# Predict:         yolo predict task=detect model=C:\Users\chena\Desktop\EZLift\model_training\runs\detect\pallets\weights\best_saved_model\best_float32.tflite imgsz=640
# Validate:        yolo val task=detect model=C:\Users\chena\Desktop\EZLift\model_training\runs\detect\pallets\weights\best_saved_model\best_float32.tflite imgsz=640 data=model_training/datasets/pallets_dataset/data.yaml
# Visualize:       https://netron.app
# 'C:\\Users\\chena\\Desktop\\EZLift\\model_training\\runs\\detect\\pallets\\weights\\best_saved_model\\best_float32.tflite'

# %%
picam2 = Picamera2()
picam2.preview_configuration.main.size = (640, 640)
picam2.preview_configuration.main.format = "RGB888"
picam2.preview_configuration.align()
# picam2.configure("preview")
# picam2.start()
picam2.start(show_preview=False)

while True:
    # Capture frame-by-frame
    frame = picam2.capture_array()

    # Run YOLO11 inference on the frame
    results = model(frame)

    # Visualize the results on the frame
    annotated_frame = results[0].plot()

    # Display the resulting frame
    cv2.imshow("Camera", annotated_frame)

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) == ord("q"):
        break

cv2.destroyAllWindows()
# Out:
# [1:01:08.395392344] [4523]  INFO Camera camera_manager.cpp:327 libcamera v0.4.0+53-29156679
# [1:01:08.435638834] [4546]  WARN RPiSdn sdn.cpp:40 Using legacy SDN tuning - please consider moving SDN inside rpi.denoise
# [1:01:08.437759274] [4546]  WARN RPI vc4.cpp:393 Mismatch between Unicam and CamHelper for embedded data usage!
# [1:01:08.438404211] [4546]  INFO RPI vc4.cpp:447 Registered camera /base/soc/i2c0mux/i2c@1/imx219@10 to Unicam device /dev/media2 and ISP device /dev/media0
# [1:01:08.438447210] [4546]  INFO RPI pipeline_base.cpp:1121 Using configuration file '/usr/share/libcamera/pipeline/rpi/vc4/rpi_apps.yaml'
# [1:01:08.449354532] [4523]  INFO Camera camera.cpp:1202 configuring streams: (0) 640x640-RGB888 (1) 640x480-SBGGR10_CSI2P
# [1:01:08.449809619] [4546]  INFO RPI vc4.cpp:622 Sensor: /base/soc/i2c0mux/i2c@1/imx219@10 - Selected sensor format: 640x480-SBGGR10_1X10 - Selected unicam format: 640x480-pBAA
# Loading /home/pi/EZLift/model_training/runs/detect/pallets/weights/best_ncnn_model for NCNN inference...
#
# 0: 640x640 1 pallet, 437.1ms
# Speed: 17.6ms preprocess, 437.1ms inference, 32.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 422.7ms
# Speed: 16.5ms preprocess, 422.7ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 512.2ms
# Speed: 15.9ms preprocess, 512.2ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 427.4ms
# Speed: 10.3ms preprocess, 427.4ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pallet, 437.1ms
# Speed: 11.0ms preprocess, 437.1ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pallet, 417.4ms
# Speed: 12.7ms preprocess, 417.4ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pallet, 432.3ms
# Speed: 12.8ms preprocess, 432.3ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pallet, 429.1ms
# Speed: 12.0ms preprocess, 429.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pallet, 425.0ms
# Speed: 14.3ms preprocess, 425.0ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 425.0ms
# Speed: 15.4ms preprocess, 425.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 420.1ms
# Speed: 11.3ms preprocess, 420.1ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 443.1ms
# Speed: 11.6ms preprocess, 443.1ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 411.3ms
# Speed: 10.3ms preprocess, 411.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 416.7ms
# Speed: 10.5ms preprocess, 416.7ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 429.3ms
# Speed: 11.8ms preprocess, 429.3ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 419.5ms
# Speed: 13.2ms preprocess, 419.5ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 419.3ms
# Speed: 11.2ms preprocess, 419.3ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 422.8ms
# Speed: 12.7ms preprocess, 422.8ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 423.1ms
# Speed: 13.3ms preprocess, 423.1ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 426.7ms
# Speed: 13.6ms preprocess, 426.7ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 411.0ms
# Speed: 12.1ms preprocess, 411.0ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 420.2ms
# Speed: 14.2ms preprocess, 420.2ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 432.3ms
# Speed: 12.1ms preprocess, 432.3ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 418.1ms
# Speed: 13.2ms preprocess, 418.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 437.8ms
# Speed: 12.9ms preprocess, 437.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 422.8ms
# Speed: 16.1ms preprocess, 422.8ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 445.6ms
# Speed: 11.7ms preprocess, 445.6ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 423.2ms
# Speed: 17.7ms preprocess, 423.2ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 pallet, 425.8ms
# Speed: 12.4ms preprocess, 425.8ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 427.2ms
# Speed: 12.3ms preprocess, 427.2ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 434.6ms
# Speed: 10.7ms preprocess, 434.6ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections),